# %% [markdown]
# # Standard Test Patterns

# %%
from xdesign import *
from xdesign.material import SlantedSquares, DogaCircles
import numpy as np
import matplotlib.pyplot as plt

def sidebyside(p):
    '''Displays the geometry and the discrete mass_atten property function of the given phantom side by side.'''
    fig = plt.figure()
    axis = fig.add_subplot(121, aspect='equal')
    plt.grid('on')
    plt.gca().invert_yaxis()
    plot_phantom(p, axis=axis)
    plt.subplot(1,2,2)
    plt.imshow(discrete_phantom(p,100), cmap=plt.cm.inferno)
    plt.show()

# %%
p = SlantedSquares(count=16, angle=5/360*2*np.pi, gap=0.01)
sidebyside(p)

# %%
h = HyperbolicConcentric()
sidebyside(h)

# %%
u = UnitCircle(radius=0.4, mass_atten=1) 
sidebyside(u)

# %%
d = DynamicRange(steps=16, jitter=True, shape='square')
sidebyside(d)

# %%
l = DogaCircles()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-5c14956315a0> in <module>()
# ----> 1 l = DogaCircles()
#
# /home/beams0/B242827/Documents/xdesign/xdesign/material.py in __init__(self, n_sizes, size_ratio, n_shuffles)
#     246         top_row = np.ones((1, n_sizes))
#     247         for i in range(0, n_sizes):
# --> 248             top_row[i] = largest/(size_ratio**i)
#     249
#     250         print(top_row)
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
a = np.ones(4)
a
# Out:
# array([ 1.,  1.,  1.,  1.])
